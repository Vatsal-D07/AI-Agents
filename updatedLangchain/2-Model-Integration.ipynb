# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
# model = init_chat_model('llama-3.3-70b-versatile')/

# %%
# model.invoke("heloo how are you ")

# %% [markdown]
# Google and GROQ

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    "groq:llama-3.3-70b-versatile"
)
res = model.invoke("Why do dog bark?")
res.content
# Out:
# 'Dogs bark for a variety of reasons, including:\n\n1. **Alerting or warning**: Dogs may bark to alert their owners to potential threats, such as strangers, other animals, or suspicious noises.\n2. **Communication**: Barking is a primary way for dogs to communicate with their human family members and other dogs. They may bark to initiate play, express excitement or enthusiasm, or to get attention.\n3. **Anxiety or stress**: Some dogs may bark due to anxiety or stress caused by separation, noise phobias, or changes in their environment.\n4. **Boredom or loneliness**: Dogs who are left alone for extended periods or don\'t receive enough mental and physical stimulation may bark out of boredom or loneliness.\n5. **Playfulness**: Dogs may bark during play, such as when they\'re playing fetch or chasing each other.\n6. **Territorial defense**: Dogs may bark to defend their territory or resources, such as food or toys.\n7. **Medical issues**: Some dogs may bark due to medical issues, such as
# ...

# %%
# model.invoke("Why do dog bark?")
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
res = model.invoke("Why dogs bark?")
res.content
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ...

# %% [markdown]
# Streaming and Batch

# %%
model.invoke("write me 200 words paragraph on AI")
# Out:
# AIMessage(content="The emergence of Artificial Intelligence (AI) has revolutionized the way we live, work, and interact with technology. AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. With the ability to process vast amounts of data, AI algorithms can identify patterns, make predictions, and optimize outcomes. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI is increasingly integrated into our daily lives. Moreover, AI has the potential to transform industries such as healthcare, finance, and education, by improving diagnosis accuracy, detecting fraud, and enhancing student learning outcomes. As AI continues to advance, it is expected to augment human capabilities, freeing us from mundane tasks and enabling us to focus on more creative and strategic endeavors. However, as AI becomes more pervasive, it 
# ...

# %%
for chunk in model.stream("write me 200 words paragraph on AI"):
    print(chunk.text)
# Out:
# Art
# ificial
#  Intelligence
#  (
# AI
# )
#  has
#  revolution
# ized
#  the
#  way
#  we
#  live
# ,
#  work
# ,
#  and
#  interact
#  with
#  technology
# .
#  With
#  its
#  ability
#  to
#  learn
# ,
#  reason
# ,
#  and
#  adapt
# ,
#  AI
#  has
#  become
#  an
#  integral
#  part
#  of
#  various
#  industries
# ,
#  from
#  healthcare
#  and
#  finance
#  to
#  transportation
#  and
#  education
# .
#  AI
# -powered
#  systems
#  can
#  analyze
#  vast
#  amounts
#  of
#  data
# ,
#  identify
#  patterns
# ,
#  and
#  make
#  decisions
#  faster
#  and
#  more
#  accurately
#  than
#  humans
# .
#  For
#  instance
# ,
#  virtual
#  assistants
#  like
#  Siri
#  and
#  Alexa
#  use
#  natural
#  language
#  processing
#  to
#  understand
#  voice
#  commands
# ,
#  while
#  self
# -driving
#  cars
#  rely
#  on
#  machine
#  learning
#  algorithms
#  to
#  navigate
#  roads
#  and
#  avoid
#  obstacles
# .
#  Moreover
# ,
#  AI
#  has
#  enabled
#  the
#  development
#  of
# ...
